# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98c3e14e-ec75-4396-98b6-420e83512d1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98c3e14e-ec75-4396-98b6-420e83512d1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.listdir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1889/3107782787.py in <cell line: 0>()
# ----> 1 os.listdir()
#
# NameError: name 'os' is not defined

# %%
import os

# %%
os.listdir()
# Out:
# ['.config', 'Equal.csv', 'sentiment.csv', 'RATIO.csv', 'sample_data']

# %%
import pandas as pd

files = ["Equal.csv", "sentiment.csv", "RATIO.csv"]

for file in files:
    print("\n==============================")
    print("FILE:", file)
    print("==============================")

    df_temp = pd.read_csv(file)

    print("Shape:", df_temp.shape)
    print("Columns:", df_temp.columns.tolist())
    display(df_temp.head())
# Out:
# ...
# FILE: Equal.csv
# ...
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_1889/4263106081.py in <cell line: 0>()
#       8     print("==============================")
#       9
# ---> 10     df_temp = pd.read_csv(file)
#      11
#      12     print("Shape:", df_temp.shape)
#
# ...

# %%
import pandas as pd

files = ["Equal.csv", "sentiment.csv", "RATIO.csv"]

for file in files:
    print("\n==============================")
    print("FILE:", file)
    print("==============================")

    try:
        df_temp = pd.read_csv(file, encoding="utf-8")
    except UnicodeDecodeError:
        df_temp = pd.read_csv(file, encoding="latin1")

    print("Shape:", df_temp.shape)
    print("Columns:", df_temp.columns.tolist())
    display(df_temp.head())
# Out:
# ...
# FILE: Equal.csv
# ...
# Shape: (76704, 6)
# Columns: ['product_name', 'product_price', 'Rate', 'Review', 'Summary', 'Sentiment']
#                                         product_name product_price Rate  \
# 0  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    4
# 1  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    4
# 2  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    4
# 3  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    2
# 4  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    5
#
#                  Review                                     Summary Sentiment
# 0  good quality product                                good cuality  positive
# 1             wonderful                               super product  positive
# 2       value-for-money                                as expected   positive
# 3              not good  meteriyal is not good but very comfortable  positive
# ...

# %%
import pandas as pd

df = pd.read_csv("Equal.csv", encoding="latin1", low_memory=False)

df.head()
# Out:
#                                         product_name product_price Rate  \
# 0  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    4
# 1  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    4
# 2  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    4
# 3  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    2
# 4  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449    5
#
#                  Review                                     Summary Sentiment
# 0  good quality product                                good cuality  positive
# 1             wonderful                               super product  positive
# 2       value-for-money                                as expected   positive
# 3              not good  meteriyal is not good but very comfortable  positive
# 4   best in the market!                                         god  positive

# %%
df = df.rename(columns={
    "ProductName": "product_name",
    "ProductPrice": "product_price",
    "Rate": "rating",
    "Review": "review_title",
    "Summary": "review_text",
    "Sentiment": "sentiment"
})

df.head()
# Out:
#                                         product_name product_price rating  \
# 0  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      4
# 1  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      4
# 2  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      4
# 3  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      2
# 4  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      5
#
#            review_title                                 review_text sentiment
# 0  good quality product                                good cuality  positive
# 1             wonderful                               super product  positive
# 2       value-for-money                                as expected   positive
# 3              not good  meteriyal is not good but very comfortable  positive
# 4   best in the market!                                         god  positive

# %%
df["full_review"] = (
    df["review_title"].fillna("").astype(str) + " " +
    df["review_text"].fillna("").astype(str)
)

df[["product_name", "product_price", "rating", "full_review", "sentiment"]].head()
# Out:
#                                         product_name product_price rating  \
# 0  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      4
# 1  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      4
# 2  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      4
# 3  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      2
# 4  SportSoul Cotton Gym & Athletic Abdomen Suppor...           449      5
#
#                                          full_review sentiment
# 0                  good quality product good cuality  positive
# 1                            wonderful super product  positive
# 2                       value-for-money as expected   positive
# 3  not good meteriyal is not good but very comfor...  positive
# 4                            best in the market! god  positive

# %%
df.shape
# Out:
# (76704, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76704 entries, 0 to 76703
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   76704 non-null  object
#  1   product_price  76704 non-null  object
#  2   rating         76704 non-null  object
#  3   review_title   76704 non-null  object
#  4   review_text    76704 non-null  object
#  5   sentiment      76704 non-null  object
#  6   full_review    76704 non-null  object
# dtypes: object(7)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# product_name     0
# product_price    0
# rating           0
# review_title     0
# review_text      0
# sentiment        0
# full_review      0
# dtype: int64

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# positive    25913
# neutral     25790
# negative    25001
# Name: count, dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# 5                                                               20501
# 1                                                               20246
# 3                                                               18371
# 4                                                                9120
# 2                                                                8465
# Pigeon Favourite Electric Kettle??????(1.5 L, Silver, Black)        1
# Name: count, dtype: int64

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

df["clean_price"] = (
    df["product_price"]
    .astype(str)
    .str.replace(r"[^0-9.]", "", regex=True)
)

df["clean_price"] = pd.to_numeric(df["clean_price"], errors="coerce")

# %%
df[["product_price", "clean_price", "rating"]].head()
# Out:
#   product_price  clean_price  rating
# 0           449          449     4.0
# 1           449          449     4.0
# 2           449          449     4.0
# 3           449          449     2.0
# 4           449          449     5.0

# %%
pd.crosstab(df["rating"], df["sentiment"])
# Out:
# sentiment  negative  neutral  positive
# rating
# 1.0           16473     3501       272
# 2.0            5244     3072       149
# 3.0            3212    13583      1576
# 4.0              36     2728      6356
# 5.0              36     2906     17559

# %%
df_clean = df[[
    "product_name",
    "clean_price",
    "rating",
    "full_review",
    "sentiment"
]].copy()

df_clean = df_clean.dropna(subset=["full_review", "sentiment", "rating"])

df_clean.head()
# Out:
#                                         product_name  clean_price  rating  \
# 0  SportSoul Cotton Gym & Athletic Abdomen Suppor...          449     4.0
# 1  SportSoul Cotton Gym & Athletic Abdomen Suppor...          449     4.0
# 2  SportSoul Cotton Gym & Athletic Abdomen Suppor...          449     4.0
# 3  SportSoul Cotton Gym & Athletic Abdomen Suppor...          449     2.0
# 4  SportSoul Cotton Gym & Athletic Abdomen Suppor...          449     5.0
#
#                                          full_review sentiment
# 0                  good quality product good cuality  positive
# 1                            wonderful super product  positive
# 2                       value-for-money as expected   positive
# 3  not good meteriyal is not good but very comfor...  positive
# 4                            best in the market! god  positive

# %%
df_clean.shape

# %%
df_clean.to_csv("marketmind_clean_reviews.csv", index=False)

# %%
df_clean.shape
# Out:
# (76703, 5)

# %%
df_clean.isnull().sum()
# Out:
# product_name    0
# clean_price     0
# rating          0
# full_review     0
# sentiment       0
# dtype: int64

# %%
from google.colab import files

files.download("marketmind_clean_reviews.csv")

# %% [markdown]
# # Phase 1 Dataset Selection
#
# The earlier dataset with only `review` and `label` columns was not suitable for MarketMind AI because the reviews looked synthetic and lacked product context.
#
# The new dataset `Equal.csv` is more suitable because it contains product name, price, rating, review title, review summary, and sentiment label.
#
# Important columns:
# - `ProductName`: product being reviewed
# - `ProductPrice`: product price
# - `Rate`: customer rating
# - `Review`: short review title
# - `Summary`: detailed customer feedback
# - `Sentiment`: sentiment label
#
# For ML preprocessing, `Review` and `Summary` will be combined into a new column called `full_review`.
